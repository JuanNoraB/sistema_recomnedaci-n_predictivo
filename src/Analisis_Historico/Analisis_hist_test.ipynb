# %% [markdown]
# ### Analisis Historico Test
# ##### Numero de transacciones por familia 5 grupos

# %%
import pandas as pd
path_historico = "../../Data/Historico_08122025.csv"
pat_test = "../../Data/data_test.csv"
group_by_columns = ['CODIGO_FAMILIA']

# %%
df_historico = pd.read_csv(path_historico,sep=';',encoding='utf-8')
# Out:
# /tmp/ipykernel_94480/1713401162.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_historico = pd.read_csv(path_historico,sep=';',encoding='utf-8')

# %%
#MOSTRAR TODO EL DATAFRAME COLUMNS Y ROWS
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df_historico["DIM_PERIODO"] = pd.to_datetime(df_historico["DIM_PERIODO"], format="%d-%b-%y")

# %%
df_gb_subcategoria = df_historico.groupby(['CODIGO_FAMILIA', 'COD_SUBCATEGORIA'])

# %%
df_hist_gb =df_hist_gb.sort_values(by='numero_transacciones', ascending=False).reset_index(drop=True)

# %%
df_hist_gb['quintil'] = pd.qcut(
    x = df_hist_gb['numero_transacciones'],
    q = 5,
    labels = [1,2,3,4,5]
)

# %%
df_hist_gb.groupby("quintil")['numero_transacciones'].mean()
# Out:
# /tmp/ipykernel_287537/489633083.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_hist_gb.groupby("quintil")['numero_transacciones'].mean()
# quintil
# 1    168.743151
# 2    267.024221
# 3    363.050788
# 4    496.716263
# 5    955.923875
# Name: numero_transacciones, dtype: float64

# %%
import pandas as pd
from pathlib import Path

# Ruta del archivo problemático
hist_file = Path("/home/juanchx/Documents/Trabajo/SYSTEM_RECOMENDATION_FNN/Data/Historico_08122025.csv")

print("🔍 Verificando columnas del archivo...")
df = pd.read_csv(hist_file, nrows=5, encoding='utf-8')
print(f"\nColumnas actuales:")
print(df.columns.tolist())

print(f"\n¿Existe 'DIM_PERIODO'? {'SÍ' if 'DIM_PERIODO' in df.columns else 'NO'}")

# Mostrar primeras filas
print(f"\nPrimeras 2 filas:")
print(df.head(2))
# Out:
# 🔍 Verificando columnas del archivo...
#
# Columnas actuales:
# ['IDENTIFICACION', 'COD_SUBCATEGORIA', 'NOMBRE_SUBCATEGORIA', 'NOMBRE_UNIDAD_COMERCIAL', 'COD_CATEGORIA', 'NOMBRE_CATEGORIA', 'COD_UNIDAD_COMERCIAL', 'COD_ITEM', 'NOMBRE_ITEM', 'DIM_PERIODO', 'CANTIDAD_SUELTA', 'CANTIDAD_CAJA', 'PVP', 'VENTA_NETA', 'MARGEN_FRONT', 'DESCUENTO', 'DIM_FACTURA', 'COD_LOCAL', 'NOMBRE_LOCAL', 'LATITUD', 'LONGITUD', 'SERVICIO_DOMICILIO', 'CODIGO_FAMILIA', 'COD_CANAL', 'NOMBRE_CANAL', 'COD_CLASIFICACION', 'NOMBRE_CLASIFICACION', 'COD_SUBCLASIFICACION', 'NOMBRE_SUBCLASIFICACION', 'NOMBRE_DIVISION_COMERCIAL', 'COD_DIVISION_COMERCIAL', 'TIPO']
#
# ¿Existe 'DIM_PERIODO'? SÍ
#
# Primeras 2 filas:
#    IDENTIFICACION  COD_SUBCATEGORIA             NOMBRE_SUBCATEGORIA  \
# 0      1703359438              8776                          CHICLE
# 1      1703359438              8971  CUIDADO CAPILAR ACONDICIONADOR
#
#   NOMBRE_UNIDAD_COMERCIAL  COD_CATEGORIA NOMBRE_CATEGORIA  \
# ...
